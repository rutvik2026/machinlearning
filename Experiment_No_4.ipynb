# %% [markdown]
# <a href="https://colab.research.google.com/github/rutvik2026/machinlearning/blob/main/Experiment_No_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as  plt
import matplotlib.mlab as mlab

# %%
a=pd.read_csv("/1709018943631_1709018913702_1. Simple linear regression.csv")
a.head(84)
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
x=a['SAT']
y=a['GPA']
plt.scatter(x,y)
plt.xlabel('SAT')
plt.ylabel('GPA')
yhat=0.2750+0.0017*x
plt.plot(x,yhat,lw=2,color='red',label='regression')
plt.show()
